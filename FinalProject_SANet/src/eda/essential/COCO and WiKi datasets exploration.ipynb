# %%
import sys
sys.path.insert(1, '../../')

from utils import *
from matplotlib import pyplot as plt

# %%
WiKi_Path = '../../../_input/style/'
COCO_Path = '../../../_input/content/'

# %%
print('Count of style (WiKi) dataset\'s images', len(list_images(WiKi_Path)))
print('Count of content (MSCOCO) dataset\'s images', len(list_images(COCO_Path)))
# Out:
# Count of style (WiKi) dataset's images 75390
# Count of content (MSCOCO) dataset's images 82783

# %%
style_image = get_images(list_images(WiKi_Path)[0])
content_image = get_images(list_images(COCO_Path)[0])

# %%
plt.imshow(style_image[0, :, :, :])

# %%
plt.imshow(content_image[0, :, :, :])
