# %%
from __future__ import print_function

import sys
import warnings
import traceback
import numpy as np

# from os import remove
from os import listdir
from os.path import join
from datetime import datetime
from scipy.misc import imread, imresize

# %%
import sys
sys.path.insert(1, '../../')

from libs.utils import *

# %%
DATA_SET_PATH = '../../../_input/style/'

# %%
def main(dir_path):
    warnings.filterwarnings('error')
    warnings.filterwarnings('ignore', category=DeprecationWarning)

    paths = list_images(dir_path)
    
    remove = []

    print('\nOrigin files number: %d\n' % len(paths))

    num_delete = 0

    for path in paths:
        is_continue = False

        try:
            image = imread(path, mode='RGB')
        except Warning as warn:
            is_continue = True
            num_delete += 1
            remove.append(path)

            print('>>> Warning happens! Removes image <%s>' % path)
            print('Warning detail:\n%s\n' % str(warn))
        except Exception as exc:
            is_continue = True
            num_delete += 1
            remove.append(path)

            print('>>> Exception happens! Removes image <%s>' % path)
            print('Exception detail:\n%s\n' % str(exc))

        if is_continue:
            continue

        if len(image.shape) != 3 or image.shape[2] != 3:
            num_delete += 1
            remove.append(path)

            print('>>> Found an image with shape: %s; Now removes it: <%s>\n' % (str(image.shape), path))
        else:
            height, width, _ = image.shape

            if height < width:
                new_height = 512
                new_width  = int(width * new_height / height)
            else:
                new_width  = 512
                new_height = int(height * new_width / width)

            try:
                image = imresize(image, [new_height, new_width], interp='nearest')
            except:
                num_delete += 1
                remove.append(path)
                
                print('>>> Fails to resize an image! Now removes it: <%s>\n' % path)
                traceback.print_exception(*sys.exc_info())

    print('\n>>>>> delete %d files! Current number of files: %d\n' % (num_delete, len(paths) - num_delete))
    return remove

# %%
t0 = datetime.now()

images_to_be_dilited = main(DATA_SET_PATH)

print('Elapsed time: %s\n' % (datetime.now() - t0))
# Out:
# Origin files number: 75390
#
# >>> Warning happens! Removes image <../../../_input/style/4436.jpg>
# Warning detail:
# Image size (129086580 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#
# >>> Found an image with shape: (); Now removes it: <../../../_input/style/92899.jpg>
#
# >>> Found an image with shape: (); Now removes it: <../../../_input/style/91033.jpg>
#
# >>> Found an image with shape: (); Now removes it: <../../../_input/style/41945.jpg>
#
# >>> Exception happens! Removes image <../../../_input/style/98873.jpg>
# Exception detail:
# Image size (283327979 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
#
# >>> Warning happens! Removes image <../../../_input/style/3321.jpg>
# Warning detail:
# Image size (131790400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#
# >>> Exception happens! Removes image <../../../_input/style/33557.jpg>
# Exception detail:
# Image size (746700000 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
#
# >>> Exception happens! Removes image <../../../_input/style/82594.jpg>
# Exception detail:
# Image size (698700000 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
#
# >>> Warning happens! Removes image <../../../_input/style/38814.jpg>
# Warning detail:
# Image size (94435468 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#
# >>> Found an image with shape: (); Now removes it: <../../../_input/style/101947.jpg>
#
# >>> Exception happens! Removes image <../../../_input/style/72255.jpg>
# Exception detail:
# Image size (888150000 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
#
# >>> Warning happens! Removes image <../../../_input/style/75232.jpg>
# Warning detail:
# Image size (99962094 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#
# >>> Warning happens! Removes image <../../../_input/style/46794.jpg>
# Warning detail:
# Image size (95799284 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#
# >>> Found an image with shape: (); Now removes it: <../../../_input/style/3917.jpg>
#
# >>> Exception happens! Removes image <../../../_input/style/50420.jpg>
# Exception detail:
# Image size (680730000 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
#
# >>> Exception happens! Removes image <../../../_input/style/81823.jpg>
# Exception detail:
# Image size (669000000 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
#
# >>> Found an image with shape: (); Now removes it: <../../../_input/style/79499.jpg>
#
# >>> Warning happens! Removes image <../../../_input/style/102257.jpg>
# Warning detail:
# Image size (107327830 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#
# >>> Found an image with shape: (); Now removes it: <../../../_input/style/95347.jpg>
#
# >>> Warning happens! Removes image <../../../_input/style/32649.jpg>
# Warning detail:
# Image size (129097476 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#
# >>> Exception happens! Removes image <../../../_input/style/95010.jpg>
# Exception detail:
# Image size (636480000 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
#
#
# >>>>> delete 21 files! Current number of files: 75369
#
# Elapsed time: 0:45:34.521135

# %%
images_to_be_dilited
# Out:
# ['../../../_input/style/4436.jpg',
#  '../../../_input/style/92899.jpg',
#  '../../../_input/style/91033.jpg',
#  '../../../_input/style/41945.jpg',
#  '../../../_input/style/98873.jpg',
#  '../../../_input/style/3321.jpg',
#  '../../../_input/style/33557.jpg',
#  '../../../_input/style/82594.jpg',
#  '../../../_input/style/38814.jpg',
#  '../../../_input/style/101947.jpg',
#  '../../../_input/style/72255.jpg',
#  '../../../_input/style/75232.jpg',
#  '../../../_input/style/46794.jpg',
#  '../../../_input/style/3917.jpg',
#  '../../../_input/style/50420.jpg',
#  '../../../_input/style/81823.jpg',
#  '../../../_input/style/79499.jpg',
#  '../../../_input/style/102257.jpg',
#  '../../../_input/style/95347.jpg',
#  '../../../_input/style/32649.jpg',
#  '../../../_input/style/95010.jpg']
