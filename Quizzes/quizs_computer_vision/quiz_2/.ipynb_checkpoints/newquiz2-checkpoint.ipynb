# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# images_name = ['./imgs/IMG_20190404_153953657.jpg']
# images_name = ['./imgs/IMG_20190404_153953657.jpg','./imgs/IMG_20190404_153954488.jpg']
# images_name = ['./imgs/IMG_20190404_153953657.jpg','./imgs/IMG_20190404_153954488.jpg','./imgs/IMG_20190404_154000947.jpg',
#               './imgs/IMG_20190404_154002764.jpg','./imgs/IMG_20190404_154004200.jpg']
images_name = ['target.jpg']
images = []
for img_name in images_name:
    img = cv2.imread(img_name)
    images.append(img)
    
imgpoints = ([],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [],
             [])
wolrdpoints = ([0,0,0],
             [20,0,0],
             [40,0,0],
             [0,20,0],
             [20,20,0],
             [40,20,0],
             [0,40,0],
             [20,40,0],
             [40,40,0],
             [0,60,0],
             [20,60,0],
             [40,60,0],
             [0,80,0],
             [20,80,0],
             [40,80,0],
             [-27.2,0,-24.5],
             [-27.2,0,-44.5],
             [-27.2,0,-64.5],
             [-27.2,20,-24.5],
             [-27.2,20,-44.5],
             [-27.2,20,-64.5],
             [-27.2,40,-24.5],
             [-27.2,40,-44.5],
             [-27.2,40,-64.5], 
             [-27.2,60,-24.5],
             [-27.2,60,-44.5],
             [-27.2,60,-64.5])

# %%
cv2.circle(images[0],(imgpoints[0][0][0][0],imgpoints[0][0][0][1]),100,(0,0,255),-1)#0,0
cv2.circle(images[0],(imgpoints[0][-1][0][0],imgpoints[0][-1][0][1]),100,(255,0,0),-1)#fim,fim
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-385-3c51e36e8f03> in <module>
# ----> 1 cv2.circle(images[0],(imgpoints[0][0][0][0],imgpoints[0][0][0][1]),100,(0,0,255),-1)#0,0
#       2 cv2.circle(images[0],(imgpoints[0][-1][0][0],imgpoints[0][-1][0][1]),100,(255,0,0),-1)#fim,fim
#       3 plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))
#       4 plt.show()
#
# IndexError: list index out of range

# %%
#####POINTS IN THE WORLD##########
worldpoints = []
#points in 1,2,3,4,5,6,7
# worldpoints = objpoints
#points i1n 0.028,0.056,0.084,0.112,0.140,0.168
for points in objpoints:
    worldpoints.append((points) * 28)
# for p in worldpoints:
#     for a in p:
#         print(a)
#     print (p)# worldpoints = worldpoints[0]
# for i,worldpoint in worldpoint[1]
for i in range(len(images_name)):
    worldpoints[i][:,2] = i
print (worldpoints)
# print (imgpoints)
# Out:
# [array([[  0.,   0.,   0.],
#        [ 28.,   0.,   0.],
#        [ 56.,   0.,   0.],
#        [ 84.,   0.,   0.],
#        [112.,   0.,   0.],
#        [140.,   0.,   0.],
#        [168.,   0.,   0.],
#        [  0.,  28.,   0.],
#        [ 28.,  28.,   0.],
#        [ 56.,  28.,   0.],
#        [ 84.,  28.,   0.],
#        [112.,  28.,   0.],
#        [140.,  28.,   0.],
#        [168.,  28.,   0.],
#        [  0.,  56.,   0.],
#        [ 28.,  56.,   0.],
#        [ 56.,  56.,   0.],
#        [ 84.,  56.,   0.],
#        [112.,  56.,   0.],
#        [140.,  56.,   0.],
#        [168.,  56.,   0.],
#        [  0.,  84.,   0.],
#        [ 28.,  84.,   0.],
#        [ 56.,  84.,   0.],
#        [ 84.,  84.,   0.],
#        [112.,  84.,   0.],
#        [140.,  84.,   0.],
#        [168.,  84.,   0.],
#        [  0., 112.,   0.],
#        [ 28., 112.,   0.],
#        [ 56., 112.,   0.],
#        [ 84., 112.,   0.],
#        [112., 112.,   0.],
#        [140., 112.,   0.],
#        [168., 112.,   0.]], dtype=float32), array([[  0.,   0.,   1.],
#        [ 28.,   0.,   1.],
#        [ 56.,   0.,   1.],
#        [ 84.,   0.,   1.],
#        [112.,   0.,   1.],
#        [140.,   0.,   1.],
#        [168.,   0.,   1.],
#        [  0.,  28.,   1.],
#        [ 28.,  28.,   1.],
#        [ 56.,  28.,   1.],
#        [ 84.,  28.,   1.],
#        [112.,  28.,   1.],
#        [140.,  28.,   1.],
#        [168.,  28.,   1.],
#        [  0.,  56.,   1.],
#        [ 28.,  56.,   1.],
#        [ 56.,  56.,   1.],
#        [ 84.,  56.,   1.],
#        [112.,  56.,   1.],
#        [140.,  56.,   1.],
#        [168.,  56.,   1.],
#        [  0.,  84.,   1.],
#        [ 28.,  84.,   1.],
#        [ 56.,  84.,   1.],
#        [ 84.,  84.,   1.],
#        [112.,  84.,   1.],
#        [140.,  84.,   1.],
#        [168.,  84.,   1.],
#        [  0., 112.,   1.],
#        [ 28., 112.,   1.],
#        [ 56., 112.,   1.],
#        [ 84., 112.,   1.],
#        [112., 112.,   1.],
#        [140., 112.,   1.],
#        [168., 112.,   1.]], dtype=float32)]

# %%
A = []
for worldpoint_vector,imgpoint_vector in zip (worldpoints,imgpoints):
    for worldpoint,imgpoint in zip(worldpoint_vector,imgpoint_vector):
#         print (worldpoint[2],imgpoint[0])
#         print(-1*imgpoint[0][1]*worldpoint[2])
        A_line = []
        A_line.append(imgpoint[0][0]*worldpoint[0])
        A_line.append(imgpoint[0][0]*worldpoint[1])
        A_line.append(imgpoint[0][0]*worldpoint[2])
        A_line.append(imgpoint[0][0])
        A_line.append(-1*imgpoint[0][1]*worldpoint[0])
        A_line.append(-1*imgpoint[0][1]*worldpoint[1])
        A_line.append(-1*imgpoint[0][1]*worldpoint[2])
        A_line.append(-1*imgpoint[0][1])
        A.append(A_line)

A = np.asarray(A)        
print (A)
print (A.shape)
# Out:
# [[      0.               0.               0.            2022.43591309
#        -0.              -0.              -0.            -806.64208984]
#  [  60598.5234375        0.               0.            2164.23291016
#    -22565.39038086      -0.              -0.            -805.90679932]
#  [ 129108.9140625        0.               0.            2305.51635742
#    -45262.88183594      -0.              -0.            -808.26574707]
#  [ 205529.15625          0.               0.            2446.77563477
#  [ 289825.46875     144912.734375      2587.72729492    2587.72729492
#   -114260.00195312  -57130.00097656   -1020.17858887   -1020.17858887]
#  [ 383141.46875     153256.59375       2736.72485352    2736.72485352
#   -142731.09375     -57092.4375       -1019.5078125    -1019.5078125 ]
#  [ 484750.71875     161583.5625        2885.42089844    2885.42089844
#   -171384.68115234  -57128.22705078   -1020.14691162   -1020.14691162]
#  [      0.          167246.9375        1991.03503418    1991.03503418
#        -0.          -96866.77587891   -1153.17590332   -1153.17590332]
#  [  59963.296875    179889.890625      2141.54638672    2141.54638672
#    -32281.60742188  -96844.82226562   -1152.91455078   -1152.91455078]
#  [ 128424.15625     192636.234375      2293.28857422    2293.28857422
#    -64725.48632812  -97088.22949219   -1155.81225586   -1155.81225586]
#  [ 205232.671875    205232.671875      2443.24609375    2443.24609375
#    -97082.66162109  -97082.66162109   -1155.74597168   -1155.74597168]
#  [ 290525.59375     217894.1875        2593.97851562    2593.97851562
#   -129436.84960938  -97077.63720703   -1155.68615723   -1155.68615723]
#  [ 384263.1875      230557.90625       2744.73706055    2744.73706055
#   -161742.82714844  -97045.69628906   -1155.3059082    -1155.3059082 ]
#  [ 486567.625       243283.8125        2896.23583984    2896.23583984
#   -193845.68847656  -96922.84423828   -1153.84338379   -1153.84338379]
#  [      0.          222599.59375       1987.49633789    1987.49633789
#        -0.         -145046.78125      -1295.06054688   -1295.06054688]
#  [  59974.26953125  239897.078125      2141.93823242    2141.93823242
#    -36264.24169922 -145056.96679688   -1295.15148926   -1295.15148926]
#  [ 128526.9296875   257053.859375      2295.1237793     2295.1237793
#    -72580.79199219 -145161.58398438   -1296.08557129   -1296.08557129]
#  [ 205646.546875    274195.375         2448.1730957     2448.1730957
#   -108851.62353516 -145135.49804688   -1295.85266113   -1295.85266113]
#  [ 291245.1875      291245.1875        2600.40356445    2600.40356445
#   -145116.71289062 -145116.71289062   -1295.68493652   -1295.68493652]
#  [ 385440.03125     308352.03125       2753.14306641    2753.14306641
#   -181487.95410156 -145190.36328125   -1296.3425293    -1296.3425293 ]
#  [ 488401.5         325601.            2907.15185547    2907.15185547
#   -217691.10644531 -145127.40429688   -1295.78039551   -1295.78039551]]
# (70, 8)

# %%
U, D, V = np.linalg.svd(A, full_matrices=True, compute_uv=True)

print ("D",D)
print ("\nV",V)
idx_min = np.argmin(D)
# idx_min = np.where(D == 0)[0]
# idx_min = len(D)-1
# print(idx_min)
V_selected = V[idx_min]
# V_selected = U[:,idx_min]
# V_selected = V[:,idx_min]
print (V_selected)
print(idx_min)
# print(V)
# print(U)
# print('*****\n',worldpoints)
# print(U.shape,V.shape)
# Out:
# D [2.75344903e+06 9.97121377e+05 1.01059779e+05 4.19443769e+04
#  1.21406350e+04 7.24852153e+03 8.68116236e+02 5.95615373e+01]
#
# V [[-8.18137471e-01 -4.35964616e-01 -3.38525468e-03 -6.81778885e-03
#    3.19286462e-01  1.96403886e-01  1.37961531e-03  2.78482542e-03]
#  [ 4.85307658e-01 -7.59898926e-01 -9.53557891e-04 -1.94679458e-03
#   -5.77570331e-02  4.28580290e-01  1.32168170e-03  2.59123747e-03]
#  [-2.71748141e-01  1.91066757e-01 -2.25286318e-02 -3.68360829e-02
#   -7.70257244e-01  5.42343126e-01  9.28429110e-03  1.62333120e-02]
#  [ 1.43795579e-01  4.42370124e-01  2.27233001e-02  3.57599627e-02
#    5.45880323e-01  6.95407222e-01 -5.77151718e-03 -1.50512173e-02]
#  [ 1.84126470e-02  1.25463002e-02 -8.75635928e-01 -2.95586814e-01
#    4.47350533e-02  2.33930277e-03  3.61638498e-01  1.12270308e-01]
#  [-1.62393954e-02 -1.14260028e-02 -2.90567835e-01  8.81097966e-01
#   -3.78365815e-02 -1.91680301e-03  1.30271076e-01 -3.47039771e-01]
#  [ 7.69110117e-04  5.51416626e-04 -3.81618594e-01 -3.26426719e-02
#    1.19315400e-03  2.75196209e-03 -9.17410788e-01 -1.07931733e-01]
#  [-2.53144904e-05  1.54169837e-03 -4.65085730e-02  3.64064997e-01
#    2.11567035e-03 -6.76671223e-04 -1.02378375e-01  9.24556644e-01]]
# [-2.53144904e-05  1.54169837e-03 -4.65085730e-02  3.64064997e-01
#   2.11567035e-03 -6.76671223e-04 -1.02378375e-01  9.24556644e-01]
# 7

# %%
gamma = (V_selected[0] ** 2 + V_selected[1] ** 2 + V_selected[2] ** 2 ) ** (1/2)
alfa = ((V_selected[4] ** 2 + V_selected[5] ** 2 + V_selected[6] ** 2 ) ** (1/2))/gamma
print(gamma, alfa)
# Out:
# 0.046534125507933496 2.200588662861142

# %%
r = np.ones(shape=(3,3))
t = np.ones(shape=(3,1))
r[1][0] = V_selected[0]/gamma
r[1][1] = V_selected[1]/gamma
r[1][2] = V_selected[2]/gamma
t[1] = V_selected[3]/gamma
r[0][0] = (V_selected[4]/alfa)/gamma
r[0][1] = (V_selected[5]/alfa)/gamma
r[0][2] = (V_selected[6]/alfa)/gamma
t[0] = (V_selected[7]/alfa)/gamma
# print (r,t)

# %%
#inner = 0 | dot = r[:][3]
r[2,:] = np.cross(r[0,:],r[1,:])

u,d,v = np.linalg.svd(r, full_matrices=True, compute_uv=True)
r = np.dot(np.dot(u,np.identity(3)),v)
print (r)
print (gamma,(gamma**2 *(r[1][0]**2 + r[1][1]**2 + r[1][2]**2)) ** (1/2),gamma ==(gamma**2 *(r[1][0]**2 + r[1][1]**2 + r[1][2]**2)) ** (1/2))
print (alfa*gamma,(alfa**2 *gamma**2 *(r[0][0]**2 + r[0][1]**2 + r[0][2]**2)) ** (1/2),alfa*gamma==(alfa**2*gamma**2 *(r[0][0]**2 + r[0][1]**2 + r[0][2]**2)) ** (1/2))
print (r[1][0]**2+r[1][1]**2+r[1][2]**2)
print (r[0][0]**2+r[0][1]**2+r[0][2]**2)
print (r[2][0]**2+r[2][1]**2+r[2][2]**2)
print("******************")
print (np.inner(r[2,:],r[0,:]),np.inner(r[2,:],r[1,:])) 
print("******************")
print (t)
# Out:
# [[ 0.33999044 -0.61445461 -0.71193541]
#  [-0.32576243  0.63321363 -0.70208215]
#  [ 0.88220482  0.47062303  0.01512036]]
# 0.046534125507933496 0.0465341255079335 False
# 0.10240246902891594 0.10240246902891596 False
# 1.0000000000000004
# 1.0000000000000004
# 0.9999999999999999
# ******************
# 6.591949208711867e-17 3.0184188481996443e-16
# ******************
# [[9.02865578]
#  [7.82361317]
#  [1.        ]]

# %%
x_aux = imgpoints[0][1][0][0] * (r[0][0] * worldpoints[0][1][0] + r[0][1] * worldpoints[0][1][1] +
                                    r[0][2] * worldpoints[0][1][2] + t[0])

print(x_aux,imgpoints[0][1][0][0],worldpoints[0][1],imgpoints[0][1][0][1] )
if x_aux > 0:
    r[0,:] = -r[0,:]
    r[1,:] = -r[1,:]
    t[0:2] = -t[0:2]

A_2 = []
for worldpoint_vector,imgpoints_vector in zip(worldpoints,imgpoints):
    for worldpoint,imgpoint in zip(worldpoint_vector,imgpoints_vector):
        A_line = []
        A_line.append(imagepoint[0][0])
        A_line.append(r[0][0] * worldpoint[0] + r[0][1] * worldpoint[1] + r[0][2] * worldpoint[2] + t[0][0])
        A_2.append(A_line)

A_2 = np.asarray(A_2)
# print (A_2.shape)
b = []
for worldpoint_vector,imgpoints_vector in zip(worldpoints,imgpoints):
    for worldpoint,imgpoint in zip(worldpoint_vector,imgpoints_vector):
        b.append(-imagepoint[0][0]* (r[2][0] * worldpoint[0] + r[2][1] * worldpoint[1] + r[2][2] * worldpoint[2]))

b = np.asarray(b)
# t[0][0]
# Out:
# [40143.03220475] 2164.233 [28.  0.  0.] 805.9068

# %%
np.dot(np.dot(np.linalg.inv(np.dot(np.transpose(A_2), A_2)), np.transpose(A_2)), b)
# Out:
# array([ -99.02726687, 1483.6255894 ])

# %%
np.dot(np.linalg.pinv(A_2),b)
# Out:
# array([ -99.02726687, 1483.6255894 ])

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
print('mtx:',mtx,'\ndist:',
      dist,'\nrvecs',rvecs,'\ntvecs:',tvecs)
# Out:
# mtx: [[3.16032705e+03 0.00000000e+00 2.34114256e+03]
#  [0.00000000e+00 3.34979612e+03 1.87498796e+03]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# dist: [[ 4.62610475e-01 -4.25878075e+00  1.64572867e-02  8.06397142e-03
#    1.70727558e+01]]
# rvecs [array([[-0.49849318],
#        [-0.04501366],
#        [-0.01742537]]), array([[-0.35445757],
#        [-0.04400605],
#        [-0.01163353]])]
# tvecs: [array([[-2.26786149],
#        [-7.15078418],
#        [22.5075704 ]]), array([[-2.38126562],
#        [-7.32410686],
#        [22.04101863]])]
